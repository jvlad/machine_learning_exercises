# %%
import numpy as np
import random

from baseUtils import todo

input_size = 2
hidden_size = 4
output_size = 1

# Define the sigmoid activation function
def sigmoid(x):
    # YOUR CODE HERE
    return

# Define the derivative of the sigmoid function
def sigmoid_derivative(x):
    # YOUR CODE HERE
    return

# Define the feedforward neural network class
class NeuralNetwork:
    def __init__(self, input_size, hidden_size, output_size):
        # 2. Initialize the network architecture
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size

        # 3. Initialize the weights  and learning rate
        # self.input_layer_features = np.random.rand(self.input_size)
        self.input_weights = np.random.rand(self.input_size, self.hidden_size)
        self.input_biases = np.random.rand(self.hidden_size)
        self.learning_rate = random.random()

    def forward(self, X):
        todo("Ensure the shape of X matches [input_size] [2024-01-24]", "nice to have")
        hidden_layer = np.dot(X, self.input_weights)
        todo("Add the biases to the hidden layer [2024-01-24]")
        todo("Apply the activation function to the hidden layer [2024-01-24]")
        todo("Compute the output layer [2024-01-24]")
        for input_set in X:  
            hidden_layer_item = np.dot(input_set, self.input_weights)
            hidden_layer.append(hidden_layer_item)
        hidden_layer = np.array(hidden_layer)
        
        0


    def backprop(self, y, output):
      # 6. implement the backpropagation process
      # YOUR CODE HERE
      output_delta = 0.
      hidden_layer_delta = 0.

      return output_delta, hidden_layer_delta

    def update_weights_and_biases(self, output_delta, hidden_layer_delta):
      # 7. update the weights and biases
      # YOUR CODE HERE
      pass

    def train(self, X, y, learning_rate, epochs):
        for epoch in range(epochs):
            # Forward propagation
            output = self.forward(X)

            # Compute the loss
            loss = np.mean(np.square(y - output))

            # Backpropagation
            output_delta, hidden_layer_delta = self.backprop(y, output)

            # Update weights and biases
            self.update_weights_and_biases(output_delta, hidden_layer_delta)

            # Print the loss for tracking progress
            print(f"Epoch {epoch + 1}/{epochs}, Loss: {loss}")

    def predict(self, X):
        # Make predictions
        return self.forward(X)

# Create a neural network
model = NeuralNetwork(input_size, hidden_size, output_size)

# Generate some sample data (replace with your data)
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([[0], [1], [1], [0]])

# Train the neural network
model.train(X, y, learning_rate=0.1, epochs=1000)

# Make predictions
predictions = model.predict(X)
print("Predictions:")
print(predictions)

# Compute Accuracty of predictions
test_acc = None
print("Test Accuracy:", test_acc)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/vladzams/Desktop/zfiles/r/prsn/soul/zTasks-zLog.zent/.extras/[lrnn]-Data-science-udemy-machine-learning/src/neural_network/xor_classifier.ipynb Cell 1 line 8
#      <a href='vscode-notebook-cell:/Users/vladzams/Desktop/zfiles/r/prsn/soul/zTasks-zLog.zent/.extras/%5Blrnn%5D-Data-science-udemy-machine-learning/src/neural_network/xor_classifier.ipynb#W0sZmlsZQ%3D%3D?line=83'>84</a> y = np.array([[0], [1], [1], [0]])
#      <a href='vscode-notebook-cell:/Users/vladzams/Desktop/zfiles/r/prsn/soul/zTasks-zLog.zent/.extras/%5Blrnn%5D-Data-science-udemy-machine-learning/src/neural_network/xor_classifier.ipynb#W0sZmlsZQ%3D%3D?line=85'>86</a> # Train the neural network
# ...

# %%
# Sample usage of the neural network
if __name__ == "__main__":
    # Define input, output, and hidden layer sizes
    input_size = 2
    hidden_size = 4
    output_size = 1

    # Create a neural network
    model = NeuralNetwork(input_size, hidden_size, output_size)

    # Generate some sample data (replace with your data)
    X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
    y = np.array([[0], [1], [1], [0]])

    # Train the neural network
    model.train(X, y, learning_rate=0.1, epochs=1000)

    # Make predictions
    predictions = model.predict(X)
    print("Predictions:")
    print(predictions)

    # Compute Accuracty of predictions
    test_acc = None
    print("Test Accuracy:", test_acc)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/vladzams/Desktop/zfiles/r/prsn/soul/zTasks-zLog.zent/.extras/[lrnn]-Data-science-udemy-machine-learning/src/neural_network/xor_classifier.ipynb Cell 2 line 1
#      <a href='vscode-notebook-cell:/Users/vladzams/Desktop/zfiles/r/prsn/soul/zTasks-zLog.zent/.extras/%5Blrnn%5D-Data-science-udemy-machine-learning/src/neural_network/xor_classifier.ipynb#W1sZmlsZQ%3D%3D?line=12'>13</a> y = np.array([[0], [1], [1], [0]])
#      <a href='vscode-notebook-cell:/Users/vladzams/Desktop/zfiles/r/prsn/soul/zTasks-zLog.zent/.extras/%5Blrnn%5D-Data-science-udemy-machine-learning/src/neural_network/xor_classifier.ipynb#W1sZmlsZQ%3D%3D?line=14'>15</a> # Train the neural network
# ...
